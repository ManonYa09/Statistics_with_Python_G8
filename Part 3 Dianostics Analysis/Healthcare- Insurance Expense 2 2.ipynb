# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#CA6F1E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#283747'></span>"Predicting Insurance Charges." </div>

# %% [markdown]
# <!-- Develop a model to predict the insurance charges (**charges**). This model can help the insurance company in setting premiums more accurately. -->

# %% [markdown]
# - [1. Load the dataset](#1)
#
# - [2.Exploratory Data Anlysis(EDA)](#2)
#     - [2.1 Quick Exploration the dataset](#1.1)
#     - [2.2 Data Cleaning](#1.3)
#         - [2.3 Missing Values](#1.3.1)
#         - [2.3.2 Duplicates](#1.3.2)
#         - [2.3.3 Outliters](#1.3.3)
#     - [2.3 Deep Exloration of features in Dataset]()
#
# - [3. Diagnostics Analytics](#2.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Load the dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ManonYa09/Statistics_with_Python_G6/main/Dataset/5.%20insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Histrogram , Countplot, Scatter, groupby , pivot,

# %%
target : number, independent feature:groupby: histrgram, 
target: Number, independent: scatter plot

# %% [markdown]
# ## 2. Exploratory Data Analysis
#
# - Quick Exploration: categorical?, numerical?, missing, : head(), info()
# - Data Cleaning: `missing`, *duplicate*, `correct type`, outlier,  : columns
# - Deep explore of feature (columns, variable,), descriptive statistics:(min, mean, std,q1, q2, q3, max )
#   boxplot, histrogram, violinplot

# %% [markdown]
# ### 2.1 Quixk Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()

# %% [markdown]
# ### 2.1 Duplicated

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 2.2 Outlier

# %% [markdown]
# outlier: numerical

# %%
age, bmi, charge

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df['age'].nunique()
# Out:
# 47

# %%
df['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4])

# %%
num_columns = []
cat_columns = []
two_unique_columns = []
for column in df.columns:
    if df[column].nunique()==2:
        two_unique_columns.append(column)
    elif df[column].nunique()<=4:
        cat_columns.append(column)
    else:
        num_columns.append(column)

# %%
num_columns, cat_columns, two_unique_columns
# Out:
# (['age', 'bmi', 'children', 'charges'], ['region'], ['sex', 'smoker'])

# %%
# num_columns = []
# cat_columns = []
# two_unique_columns = []
# for column in df.columns:
#     if df[column].nunique()==2:
#         two_unique_columns.append(column)
#     elif df[column].nunique()<=6:
#         cat_columns.append(column)
#     else:
#         num_columns.append(column)

# %%
# df1 = pd.read_csv('https://raw.githubusercontent.com/ManonYa09/Statistics_with_Python_G8/main/Dataset/4.%20WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
# df1.nunique()

# %%
# num_columns = []
# cat_columns = []
# two_unique_columns = []
# for column in df.columns:
#     if df[column].nunique()==2:
#         two_unique_columns.append(column)
#     elif df[column].nunique()<=6:
#         cat_columns.append(column)
#     else:
#         num_columns.append(column)

# %%
# two_unique_columns1

# %%
# df1[two_unique_columns1]

# %%
# cat_columns1

# %%
# num_columns1

# %%
# num_columns

# %%
# cat_columns

# %%
# df[two_unique_columns]

# %%
two_unique_columns
# Out:
# ['sex', 'smoker']

# %%
sns.boxplot(data =df[num_columns]);

# %% [markdown]
# ## Deep Exloration of features in Dataset

# %%
fig , ax = plt.subplots(1 , 3, figsize = (15, 5))

sns.boxplot(data = df['age'], ax = ax[0])
ax[0].set_title('Distribution of Age', color = 'r')

sns.boxplot(data = df['bmi'], ax = ax[1])
ax[1].set_title('Distribution of BMI', color = 'b')

sns.boxplot(data= df['charges'], ax= ax[2])
ax[2].set_title('Distribution of charges', color = 'teal')
plt.show()

# %%
# fig, ax = plt.subplots(figsize = (10, 5))
# sns.histplot(x = df['charges'], bins =np.arange(0, 70000, 2500))
# ax.set_xticks(np.arange(0, 70000, 5000))
# ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# ax.set_title('Distribution of Chaeges', fontsize = 14, color ='r')
# ax.set_xlabel('Charges', fontsize=12)
# ax.set_ylabel('Frequency', fontsize=12)
# ax.bar_label(ax.containers[1])
# ax.spines[['right', 'top']].set_visible(False)

# %% [markdown]
# ### 2.3 Diagnostics Analysis

# %%
independent feature: categorical columns , target:number

# %%
df.groupby(two_unique_columns)['charges'].describe()
# Out:
#                count          mean           std         min           25%  \
# sex    smoker
# female no      547.0   8762.297300   6060.775970   1607.5101   4265.599100
#        yes     115.0  30678.996276  11907.536381  13844.5060  19696.432100
# male   no      516.0   8099.700161   5907.000174   1121.8739   3684.907500
#        yes     159.0  33042.005975  11202.670862  12829.4551  21241.526875
#
#                         50%          75%          max
# sex    smoker
# female no       7639.417450  11786.16660  36910.60803
#        yes     28950.469200  40918.31450  63770.42801
# male   no       6986.101975  10960.85900  32108.66282
#        yes     36085.219000  41797.58905  62592.87309

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = df.groupby(['smoker','region'])[['charges','bmi']].describe()

# %%
df1.columns[2]
# Out:
# ('charges', 'std')

# %%
groupby: -> age, smoker, target

# %%
sns.histplot(data = df,x = df['charges'], hue= df['smoker']);

# %%
sns.histplot(data = df,x = df['charges'], hue= df['region']);

# %%
# df.head()

# %%
fig, ax = plt.subplots(1,2,figsize = (16, 5))
sns.scatterplot(x = df['age'], y = df['charges'], hue = df['smoker'], ax = ax[0])
sns.scatterplot(x = df['bmi'], y  = df['charges'], color = 'teal', 
                hue = df['smoker'], palette=['#daf7a6', '#FFC300'], ax = ax[1]);
# sns.scatterplot(x = df['children'], y = df['charges'])

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df.groupby([ 'smoker','children', 'sex'])[['age', 'charges']].describe()
# Out:
#                           age                                                  \
#                         count       mean        std   min    25%   50%    75%
# smoker children sex
# no     0        female  236.0  38.614407  16.405488  18.0  22.00  36.0  56.00
#                 male    222.0  39.207207  16.686417  18.0  22.00  39.5  56.00
#        1        female  133.0  39.353383  11.226454  18.0  30.00  41.0  48.00
#                 male    130.0  39.392308  12.915045  18.0  30.00  40.0  50.00
#        2        female   97.0  40.783505  12.365297  18.0  31.00  42.0  52.00
#                 male     88.0  37.920455  10.191524  18.0  29.75  39.0  44.00
#        3        female   63.0  42.682540  12.014541  19.0  33.00  41.0  54.00
#                 male     55.0  40.836364  12.439131  18.0  30.00  43.0  50.50
#        3        female   6387.585800   8538.288450  12490.545875  27322.73386
#                 male     5231.551425   8410.046850  10580.520000  30063.58055
#        4        female   9110.509950  11033.661700  15111.609940  36580.28216
#                 male     6785.720000  10407.085850  12234.627625  19496.71917
#        5        female   6706.466150   8596.827800  10259.349875  12592.53450
#                 male     5874.973900   6732.850500   9647.250075  14478.33015
# yes    0        female  19964.746300  29330.983150  38792.685600  63770.42801
#                 male    20410.946675  34644.993925  39240.379900  62592.87309
#        1        female  19594.809650  23401.305750  41661.602000  58571.07448
#                 male    21754.547675  37926.560485  40463.789475  51194.55914
#        2        female  20318.745913  34377.598750  42923.115288  47305.30500
#                 male    23807.240600  38711.000000  43813.866100  49577.66240
#        3        female  22271.675713  27907.788350  40695.178612  46661.44240
#                 male    24869.836800  36189.101700  42124.515300  60021.39897
#        4        male    19707.292400  21472.478800  30827.362400  40182.24600
#        5        female  19023.260000  19023.260000  19023.260000  19023.26000

# %% [markdown]
# #### 2.3.1 Exploring Categorical Data with Target

# %%
df.groupby(two_unique)['charges'].describe()

# %% [markdown]
# #### 2.3.2 Exploring Numerical Data with Target

# %%
# sns.pairplot(data = data[num_columns], hue = data['smoker'])

# %% [markdown]
# #### age with Target

# %% [markdown]
# <!-- fig, ax =plt.subplots(1, 2 , figsize = (16, 6), )
# sns.boxplot(y = data['age'], ax =ax[0])
# ax[0].set_title('Distribution of Charges')
# ax[1].axhline(y = data['charges'].mean(), label = 'Mean of Charges', color = 'r')
# ax[1].legend()
# sns.scatterplot(x = data['age'], y = data['charges'], hue = data['smoker'], palette="deep", ax = ax[1])
# ax[1].set_xticks(np.arange(15, 66, 5))
# ax[1].set_xlabel("Age (Years)")
# ax[1].set_ylabel("Number of Charges")
# ax[1].set_title("Relationship Between Age, Charges, and Smoking Status")
# ax[1].legend(title="Smoking Status")
# plt.tight_layout()
# # plt.savefig('D&Re and Charges.jpg', dpi = 1000)
# plt.show() -->

# %% [markdown]
# <!-- fig, ax = plt.subplots(1, 2, figsize=(16, 6))
#
# sns.boxplot(y=data['bmi'], ax=ax[0])
# ax[0].set_title('Distribution of BMI')
#
# # Combined plot for 'charges' vs 'bmi' and 'smoker'
# ax[1].axhline(y=data['charges'].mean(), label='Mean of Charges', color='r')
# ax[1].legend()
# sns.scatterplot(x=data['bmi'], y=data['charges'], hue=data['smoker'], palette="deep", ax=ax[1])
# ax[1].set_xlabel("BMI")  # Update label for 'bmi'
# ax[1].set_ylabel("Number of Charges")
# ax[1].set_title("Relationship Between BMI, Charges, and Smoking Status")
# ax[1].legend(title="Smoking Status")
#
# # Adjust layout
# plt.tight_layout(rect=(0, 0, 1, 1))
# # plt.savefig('bmi.jpg', dpi = 1000)
# plt.show() -->

# %% [markdown]
# ### correlation coefficient

# %%
data[['age', 'children', 'bmi','charges']].corr()['charges']
